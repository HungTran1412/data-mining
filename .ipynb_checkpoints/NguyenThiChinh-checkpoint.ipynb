# %% [markdown]
# # Getting and Knowing Data

# %%
import pandas as pd

# %% [markdown]
# # Step 1: import dataset

# %%
df = pd.read_excel("rượu.xlsx")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.8             0.880         0.00             2.6      0.098
# 1               7.8             0.760         0.04             2.3      0.092
# 2              11.2             0.280         0.56             1.9      0.075
# 3               7.4             0.700         0.00             1.9      0.076
# 4               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.2             0.600         0.08             2.0      0.090
# 1594            5.9             0.550         0.10             2.2      0.062
# 1595            6.3             0.510         0.13             2.3      0.076
# 1596            5.9             0.645         0.12             2.0      0.075
# 1597            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.88         0.00             2.6      0.098
# 1            7.8              0.76         0.04             2.3      0.092
# 2           11.2              0.28         0.56             1.9      0.075
# 3            7.4              0.70         0.00             1.9      0.076
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   25                    67   0.9968  3.20       0.68
# 1                   15                    54   0.9970  3.26       0.65
# 2                   17                    60   0.9980  3.16       0.58
# 3                   11                    34   0.9978  3.51       0.56
# 4                   13                    40   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.8        5
# 1      9.8        5
# 2      9.8        6
# ...

# %% [markdown]
# # Step 2:Dataset Overview

# %%
df.shape
# Out:
# (1598, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1598 entries, 0 to 1597
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1598 non-null   float64
#  3   residual sugar        1598 non-null   float64
#  4   chlorides             1598 non-null   float64
#  5   free sulfur dioxide   1598 non-null   int64
#  6   total sulfur dioxide  1598 non-null   int64
#  7   density               1598 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1598 non-null   float64
#  10  alcohol               1598 non-null   float64
#  11  quality               1598 non-null   int64
# dtypes: float64(9), int64(3)
# memory usage: 149.9 KB

# %%
#print all columns' name
list(df.columns)
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1598, step=1)

# %%
df.describe(include="all")
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1598.000000     1598.000000
# mean        8.320213          0.527713     0.271145        2.539205
# std         1.741489          0.179064     0.194744        1.410279
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1598.000000          1598.000000           1598.000000  1598.000000
# mean      0.087474            15.878598             46.476220     0.996746
# std       0.047079            10.462996             32.904737     0.001888
# ...

# %% [markdown]
# # Loc và iloc

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.88         0.00             2.6      0.098
# 1            7.8              0.76         0.04             2.3      0.092
# 2           11.2              0.28         0.56             1.9      0.075
# 3            7.4              0.70         0.00             1.9      0.076
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   25                    67   0.9968  3.20       0.68
# 1                   15                    54   0.9970  3.26       0.65
# 2                   17                    60   0.9980  3.16       0.58
# 3                   11                    34   0.9978  3.51       0.56
# 4                   13                    40   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.8        5
# 1      9.8        5
# 2      9.8        6
# ...

# %%
df.loc[(df["quality"] == 5) | (df["residual sugar"] == 2)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.8             0.880         0.00             2.6      0.098
# 1               7.8             0.760         0.04             2.3      0.092
# 3               7.4             0.700         0.00             1.9      0.076
# 4               7.4             0.660         0.00             1.8      0.075
# 5               7.9             0.600         0.06             1.6      0.069
# ...             ...               ...          ...             ...        ...
# 1581            6.1             0.715         0.10             2.6      0.053
# 1582            6.2             0.460         0.29             2.1      0.074
# 1588            6.6             0.725         0.20             7.8      0.073
# 1593            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.loc[(df["quality"] == 5) & (df["residual sugar"] == 2)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 62              7.0             0.735         0.05             2.0      0.081
# 67              9.3             0.320         0.57             2.0      0.074
# 77              6.7             0.750         0.12             2.0      0.086
# 81              7.4             0.500         0.47             2.0      0.086
# 91              8.6             0.490         0.29             2.0      0.110
# ...             ...               ...          ...             ...        ...
# 1562            7.2             0.695         0.13             2.0      0.076
# 1563            7.2             0.695         0.13             2.0      0.076
# 1566            7.2             0.695         0.13             2.0      0.076
# 1593            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.loc[(df["quality"] == 5) & (df["residual sugar"] == 2) , ("residual sugar","total sulfur dioxide")]
# Out:
#       residual sugar  total sulfur dioxide
# 62               2.0                    54
# 67               2.0                    65
# 77               2.0                    80
# 81               2.0                    73
# 91               2.0                   133
# ...              ...                   ...
# 1562             2.0                    20
# 1563             2.0                    20
# 1566             2.0                    20
# 1593             2.0                    44
# 1596             2.0                    44
#
# [71 rows x 2 columns]

# %%
df.loc[(df["quality"] <= 5) & (df["residual sugar"] == 2)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 62              7.0             0.735         0.05             2.0      0.081
# 67              9.3             0.320         0.57             2.0      0.074
# 77              6.7             0.750         0.12             2.0      0.086
# 81              7.4             0.500         0.47             2.0      0.086
# 91              8.6             0.490         0.29             2.0      0.110
# ...             ...               ...          ...             ...        ...
# 1562            7.2             0.695         0.13             2.0      0.076
# 1563            7.2             0.695         0.13             2.0      0.076
# 1566            7.2             0.695         0.13             2.0      0.076
# 1593            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.iloc[7]
# Out:
# fixed acidity            7.8000
# volatile acidity         0.5800
# citric acid              0.0200
# residual sugar           2.0000
# chlorides                0.0730
# free sulfur dioxide      9.0000
# total sulfur dioxide    18.0000
# density                  0.9968
# pH                       3.3600
# sulphates                0.5700
# alcohol                  9.5000
# quality                  7.0000
# Name: 7, dtype: float64

# %%
df.iloc[8:12]
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 8             7.5             0.500         0.36             6.1      0.071
# 9             6.7             0.580         0.08             1.8      0.097
# 10            7.5             0.500         0.36             6.1      0.071
# 11            5.6             0.615         0.00             1.6      0.089
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 8                    17                   102   0.9978  3.35       0.80
# 9                    15                    65   0.9959  3.28       0.54
# 10                   17                   102   0.9978  3.35       0.80
# 11                   16                    59   0.9943  3.58       0.52
#
#     alcohol  quality
# 8      10.5        5
# 9       9.2        5
# 10     10.5        5
# 11      9.9        5

# %%
x = df.iloc[3:5, :-1]
y = df.iloc[3:5, -1]
print(y)
# Out:
# 3    5
# 4    5
# Name: quality, dtype: int64

# %% [markdown]
# # Data Manipulation

# %%
df["fixed acidity"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Apply

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.88         0.00             2.6      0.098
# 1            7.8              0.76         0.04             2.3      0.092
# 2           11.2              0.28         0.56             1.9      0.075
# 3            7.4              0.70         0.00             1.9      0.076
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   25                    67   0.9968  3.20       0.68
# 1                   15                    54   0.9970  3.26       0.65
# 2                   17                    60   0.9980  3.16       0.58
# 3                   11                    34   0.9978  3.51       0.56
# 4                   13                    40   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.8        5
# 1      9.8        5
# 2      9.8        6
# ...

# %%
df["sugar_alcohol_ratio"] = df["residual sugar"] / df["alcohol"]

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.8              0.88         0.00             2.6      0.098
# 1            7.8              0.76         0.04             2.3      0.092
# 2           11.2              0.28         0.56             1.9      0.075
# 3            7.4              0.70         0.00             1.9      0.076
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                   25                    67   0.9968  3.20       0.68
# 1                   15                    54   0.9970  3.26       0.65
# 2                   17                    60   0.9980  3.16       0.58
# 3                   11                    34   0.9978  3.51       0.56
# 4                   13                    40   0.9978  3.51       0.56
#
#    alcohol  quality  total_acidity  sugar_alcohol_ratio
# ...

# %% [markdown]
# # Calculate the total residual sugar up to now

# %%
total_sugar = df["residual sugar"].sum()
print("Tổng lượng đường dư:", total_sugar)
# Out:
# Tổng lượng đường dư: 4057.6500000000005

# %% [markdown]
# # Group By

# %%
c = df.groupby("citric acid")["residual sugar"].sum()
c.sort_values(ascending = False).head(5)
# Out:
# citric acid
# 0.00    293.60
# 0.49    203.30
# 0.24    118.55
# 0.02    117.80
# 0.32     90.60
# Name: residual sugar, dtype: float64

# %%
df["quality"].value_counts()
# Out:
# quality
# 5    680
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
df["quality"].nunique()
# Out:
# 6
